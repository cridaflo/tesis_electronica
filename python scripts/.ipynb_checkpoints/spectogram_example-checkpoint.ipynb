# %%
import librosa
import librosa.display

filename = '../maestro-v3.0.0/2018/MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1.wav'
#filename = 'output.wav'
hop_length = 128
tam = 540658
dur =  librosa.get_duration(filename=filename)
sro = tam/dur
y, sr = librosa.load(filename, sr = hop_length*sro)

#dur2 = librosa.get_duration(filename='midi-a-wav.wav')
print(y.shape, y.shape[0]/hop_length, sr, dur, dur*sr)
# trim silent edges
whale_song, _ = librosa.effects.trim(y)
librosa.display.waveplot(whale_song, sr=sr);
# Out:
# (57237310,) 447166.484375 98133.376 583.260375 57237309.685775995
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6224/3429680437.py in <module>
#      10 # trim silent edges
#      11 whale_song, _ = librosa.effects.trim(y)
# ---> 12 librosa.display.waveplot(whale_song, sr=sr);
#
# c:\users\crida\appdata\local\programs\python\python39\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\users\crida\appdata\local\programs\python\python39\lib\site-packages\librosa\util\decorators.py in __wrapper(func, *args, **kwargs)
#      54             lineno=code.co_firstlineno + 1,
#      55         )
# ---> 56         return func(*args, **kwargs)
#      57
#      58     return decorator(__wrapper)
#
# c:\users\crida\appdata\local\programs\python\python39\lib\site-packages\librosa\display.py in waveplot(y, sr, max_points, x_axis, offset, max_sr, ax, **kwargs)
#     723
#     724     # Reduce by envelope calculation
# --> 725     y = __envelope(y, hop_length)
#     726
#     727     y_top = y[0]
#
# c:\users\crida\appdata\local\programs\python\python39\lib\site-packages\librosa\display.py in __envelope(x, hop)
#     587     x is assumed to be multi-channel, of shape (n_channels, n_samples).
#     588     """
# --> 589     x_frame = np.abs(util.frame(x, frame_length=hop, hop_length=hop))
#     590     return x_frame.max(axis=1)
#     591
#
# c:\users\crida\appdata\local\programs\python\python39\lib\site-packages\librosa\util\utils.py in frame(x, frame_length, hop_length, axis)
#     224         raise ParameterError("Frame axis={} must be either 0 or -1".format(axis))
#     225
# --> 226     return as_strided(x, shape=shape, strides=strides)
#     227
#     228
#
# c:\users\crida\appdata\local\programs\python\python39\lib\site-packages\numpy\lib\stride_tricks.py in as_strided(x, shape, strides, subok, writeable)
#     102         interface['strides'] = tuple(strides)
#     103
# --> 104     array = np.asarray(DummyArray(interface, base=x))
#     105     # The route via `__interface__` does not preserve structured
#     106     # dtypes. Since dtype should remain unchanged, we set it explicitly.
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
import numpy as np
import matplotlib.pyplot as plt


n_fft = 2048
D = np.abs(librosa.stft(whale_song[:n_fft], n_fft=n_fft, hop_length=n_fft+1))
plt.plot(D);

# %%
D = np.abs(librosa.stft(whale_song, n_fft=n_fft,  hop_length=hop_length))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='linear');
plt.colorbar();

DB = librosa.amplitude_to_db(D, ref=np.max)
librosa.display.specshow(DB, sr=sr, hop_length=hop_length, x_axis='time', y_axis='log');
plt.colorbar(format='%+2.0f dB');

# %%
n_mels = 128
mel = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels)
plt.figure(figsize=(15, 4));

plt.subplot(1, 3, 1);
librosa.display.specshow(mel, sr=sr, hop_length=hop_length, x_axis='linear');
plt.ylabel('Mel filter');
plt.colorbar();
plt.title('1. Our filter bank for converting from Hz to mels.');

plt.subplot(1, 3, 2);
mel_10 = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=10)
librosa.display.specshow(mel_10, sr=sr, hop_length=hop_length, x_axis='linear');
plt.ylabel('Mel filter');
plt.colorbar();
plt.title('2. Easier to see what is happening with only 10 mels.');

plt.subplot(1, 3, 3);
idxs_to_plot = [0, 9, 49, 99, 127]
for i in idxs_to_plot:
    plt.plot(mel[i]);
plt.legend(labels=[f'{i+1}' for i in idxs_to_plot]);
plt.title('3. Plotting some triangular filters separately.');

plt.tight_layout();

# %%
plt.plot(D[:, 1]);
plt.plot(mel.dot(D[:, 1]));
plt.legend(labels=['Hz', 'mel']);
plt.title('One sampled window for example, before and after converting to mel.');

# %%
n_mels = 128
S = librosa.feature.melspectrogram(whale_song, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
S_DB = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_DB, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel');
plt.colorbar(format='%+2.0f dB')

import matplotlib.pyplot as plt


C = np.abs(librosa.cqt(y, sr=sr,  hop_length=hop_length))

fig, ax = plt.subplots()

img = librosa.display.specshow(librosa.amplitude_to_db(C, ref=np.max),

                               sr=sr, x_axis='time', y_axis='cqt_note', ax=ax)

ax.set_title('Constant-Q power spectrum')

fig.colorbar(img, ax=ax, format="%+2.0f dB")

# %% [raw]
# Esto esta tomado de este tutorial https://towardsdatascience.com/getting-to-know-the-mel-spectrogram-31bca3e2d9d0

# %%
x = librosa.amplitude_to_db(C, ref=np.max)
print(x.shape, type(x))
plt.imshow(x, cmap='hot', interpolation='nearest')
plt.show()
